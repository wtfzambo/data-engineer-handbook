// %%
import org.apache.spark.sql.functions._
import org.apache.spark.storage.StorageLevel

spark.conf.set("spark.sql.autoBroadcastJoinThreshold", "-1")
spark.conf.set("spark.sql.analyzer.failAmbiguousSelfJoin", "false")
spark.conf.set("spark.sql.shuffle.partitions", "4")

val users = spark.read.option("header", "true")
                        .option("inferSchema", "true")
                        .csv("/home/iceberg/data/events.csv")
                        .where($"user_id".isNotNull)

users.createOrReplaceTempView("events")

val devices = spark.read.option("header", "true")
                        .option("inferSchema", "true")
                        .csv("/home/iceberg/data/devices.csv")

devices.createOrReplaceTempView("devices")

val executionDate = "2023-01-01"

//Caching here should be < 5 GBs or used for broadcast join
//You need to tune executor memory otherwise it'll spill to disk and be slow
//Dont really try using any of the other StorageLevel besides MEMORY_ONLY

val eventsAggregated = spark.sql(f"""
  SELECT user_id, 
          device_id, 
        COUNT(1) as event_counts, 
        COLLECT_LIST(DISTINCT host) as host_array
  FROM events
  GROUP BY 1,2
""").cache()

// eventsAggregated.write.mode("overwrite").saveAsTable("bootcamp.events_aggregated_staging")

spark.sql(f"""
    CREATE TABLE IF NOT EXISTS bootcamp.events_aggregated_staging (
        user_id BIGINT,
        device_id BIGINT,
        event_counts BIGINT,
        host_array ARRAY<STRING>
    )
    PARTITIONED BY (ds STRING)
""")


val usersAndDevices = users
  .join(eventsAggregated, eventsAggregated("user_id") === users("user_id"))
  .groupBy(users("user_id"))
  .agg(
    users("user_id"),
    max(eventsAggregated("event_counts")).as("total_hits"),
    collect_list(eventsAggregated("device_id")).as("devices")
  )

val devicesOnEvents = devices
      .join(eventsAggregated, devices("device_id") === eventsAggregated("device_id"))
      .groupBy(devices("device_id"), devices("device_type"))
      .agg(
        devices("device_id"),
        devices("device_type"),
         collect_list(eventsAggregated("user_id")).as("users")
      )

devicesOnEvents.explain()
usersAndDevices.explain()

devicesOnEvents.take(1)
usersAndDevices.take(1)
// Out:
// == Physical Plan ==
// AdaptiveSparkPlan isFinalPlan=false
// +- ObjectHashAggregate(keys=[device_id#3254, device_type#3257], functions=[collect_list(user_id#3224, 0, 0)])
//    +- ObjectHashAggregate(keys=[device_id#3254, device_type#3257], functions=[partial_collect_list(user_id#3224, 0, 0)])
//       +- Project [device_id#3254, device_type#3257, user_id#3224]
//          +- SortMergeJoin [device_id#3254], [device_id#3225], Inner
//             :- Sort [device_id#3254 ASC NULLS FIRST], false, 0
//             :  +- Exchange hashpartitioning(device_id#3254, 4), ENSURE_REQUIREMENTS, [plan_id=4206]
//             :     +- Filter isnotnull(device_id#3254)
//             :        +- FileScan csv [device_id#3254,device_type#3257] Batched: false, DataFilters: [isnotnull(device_id#3254)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/iceberg/data/devices.csv], PartitionFilters: [], PushedFilters: [IsNotNull(device_id)], ReadSchema: struct<device_id:int,device_type:string>
//             +- Sort [device_id#3225 ASC NULLS FIRST], false, 0
//                +- Exchange hashpartitioning(device_id#3225, 4), ENSURE_REQUIREMENTS, [plan_id=4207]
//                   +- Filter isnotnull(device_id#3225)
//                      +- InMemoryTableScan [user_id#3224, device_id#3225], [isnotnull(device_id#3225)]
//                            +- InMemoryRelation [user_id#3224, device_id#3225, event_counts#3262L, host_array#3263], StorageLevel(disk, memory, deserialized, 1 replicas)
//                                  +- AdaptiveSparkPlan isFinalPlan=false
//                                     +- ObjectHashAggregate(keys=[user_id#3224, device_id#3225], functions=[count(1), collect_list(distinct host#3227, 0, 0)])
//                                        +- Exchange hashpartitioning(user_id#3224, device_id#3225, 4), ENSURE_REQUIREMENTS, [plan_id=4223]
//                                           +- ObjectHashAggregate(keys=[user_id#3224, device_id#3225], functions=[merge_count(1), partial_collect_list(distinct host#3227, 0, 0)])
//                                              +- HashAggregate(keys=[user_id#3224, device_id#3225, host#3227], functions=[merge_count(1)])
//                                                 +- Exchange hashpartitioning(user_id#3224, device_id#3225, host#3227, 4), ENSURE_REQUIREMENTS, [plan_id=4219]
//                                                    +- HashAggregate(keys=[user_id#3224, device_id#3225, host#3227], functions=[partial_count(1)])
//                                                       +- Filter isnotnull(user_id#3224)
//                                                          +- FileScan csv [user_id#3224,device_id#3225,host#3227] Batched: false, DataFilters: [isnotnull(user_id#3224)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/iceberg/data/events.csv], PartitionFilters: [], PushedFilters: [IsNotNull(user_id)], ReadSchema: struct<user_id:int,device_id:int,host:string>
//
//
// == Physical Plan ==
// AdaptiveSparkPlan isFinalPlan=false
// +- ObjectHashAggregate(keys=[user_id#3224], functions=[max(event_counts#3262L), collect_list(device_id#3225, 0, 0)])
//    +- ObjectHashAggregate(keys=[user_id#3224], functions=[partial_max(event_counts#3262L), partial_collect_list(device_id#3225, 0, 0)])
//       +- Project [user_id#3224, device_id#3225, event_counts#3262L]
//          +- SortMergeJoin [user_id#3224], [user_id#3296], Inner
//             :- Sort [user_id#3224 ASC NULLS FIRST], false, 0
//             :  +- Exchange hashpartitioning(user_id#3224, 4), ENSURE_REQUIREMENTS, [plan_id=4259]
//             :     +- Filter isnotnull(user_id#3224)
//             :        +- FileScan csv [user_id#3224,device_id#3225] Batched: false, DataFilters: [isnotnull(user_id#3224)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/iceberg/data/events.csv], PartitionFilters: [], PushedFilters: [IsNotNull(user_id)], ReadSchema: struct<user_id:int,device_id:int>
//             +- Sort [user_id#3296 ASC NULLS FIRST], false, 0
//                +- Exchange hashpartitioning(user_id#3296, 4), ENSURE_REQUIREMENTS, [plan_id=4260]
//                   +- Filter isnotnull(user_id#3296)
//                      +- InMemoryTableScan [user_id#3296, event_counts#3262L], [isnotnull(user_id#3296)]
//                            +- InMemoryRelation [user_id#3296, device_id#3297, event_counts#3262L, host_array#3263], StorageLevel(disk, memory, deserialized, 1 replicas)
//                                  +- AdaptiveSparkPlan isFinalPlan=false
//                                     +- ObjectHashAggregate(keys=[user_id#3224, device_id#3225], functions=[count(1), collect_list(distinct host#3227, 0, 0)])
//                                        +- Exchange hashpartitioning(user_id#3224, device_id#3225, 4), ENSURE_REQUIREMENTS, [plan_id=4276]
//                                           +- ObjectHashAggregate(keys=[user_id#3224, device_id#3225], functions=[merge_count(1), partial_collect_list(distinct host#3227, 0, 0)])
//                                              +- HashAggregate(keys=[user_id#3224, device_id#3225, host#3227], functions=[merge_count(1)])
//                                                 +- Exchange hashpartitioning(user_id#3224, device_id#3225, host#3227, 4), ENSURE_REQUIREMENTS, [plan_id=4272]
//                                                    +- HashAggregate(keys=[user_id#3224, device_id#3225, host#3227], functions=[partial_count(1)])
//                                                       +- Filter isnotnull(user_id#3224)
//                                                          +- FileScan csv [user_id#3224,device_id#3225,host#3227] Batched: false, DataFilters: [isnotnull(user_id#3224)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/iceberg/data/events.csv], PartitionFilters: [], PushedFilters: [IsNotNull(user_id)], ReadSchema: struct<user_id:int,device_id:int,host:string>
// import org.apache.spark.sql.functions._
// import org.apache.spark.storage.StorageLevel
// users: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [user_id: int, device_id: int ... 4 more fields]
// devices: org.apache.spark.sql.DataFrame = [device_id: int, browser_type: string ... 2 more fields]
// executionDate: String = 2023-01-01
// eventsAggregated: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [user_id: int, device_id: int ... 2 more fields]
// usersAndDevices: org.apache.spark.sql.DataFrame = [user_id: int, user_id: int ... 2 more fields]
// devicesOnEvents: org.apache.spark.sql.DataFrame = [device_id: int, device_type: string ... 3 more fields]
// res8: Array[org.apache.spark.sql.Row] = Array([-2147470439,-2147470439,3,WrappedArray(378988111, 378988111, 378988111)])

// %%
eventsAggregated.unpersist()
// Out:
// res6: eventsAggregated.type = [user_id: int, device_id: int ... 2 more fields]

// %%
StorageLevel.
